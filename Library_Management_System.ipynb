# %% [markdown]
# <a href="https://colab.research.google.com/github/nedimakdulum/Dog-Breed-Classification/blob/main/Library_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Library:
    def __init__(self, file_name="books.txt"):
        self.file_name = file_name
        self.file = open(self.file_name, "a+")

    def __del__(self):
        self.file.close()

    def list_books(self):
        self.file.seek(0)  # Move cursor to the beginning of the file
        books = self.file.readlines()
        if not books:
            print("Mevcut kitap yok.")
        else:
            print("Kitap Listesi:")
            for book in books:
                book_info = book.strip().split(',')
                title = book_info[0]
                author = book_info[1]
                print(f"Kitap Adı: {title}, Yazar Adı: {author}")

    def add_book(self):
        title = input("Kitap adını girin: ")
        author = input("Yazarın adını girin: ")
        release_year = input("Yayın yılını girin: ")
        num_pages = input("Sayfa sayısını girin:")
        book_info = f"{title},{author},{release_year},{num_pages}\n"
        self.file.write(book_info)
        print(f" '{title}' kitabı başarıyla eklendi.")

    def remove_book(self):
        title = input("Silmek istediğiniz kitabın adını girin: ")
        self.file.seek(0)
        books = self.file.readlines()
        updated_books = []
        removed = False

        for book in books:
            if title.lower() not in book.lower():
                updated_books.append(book)
            else:
                removed = True

        if removed:
            self.file.seek(0)
            self.file.truncate()  # Clear the file contents
            self.file.writelines(updated_books)
            print(f"'{title}' kitabı başarıyla silindi.")
        else:
            print(f"'{title}' kitabı bulunamadı.")

# Create an object of the Library class
lib = Library()

# Menu
while True:
    print("\n*** MENU ***")
    print("1) Kitapları Listele")
    print("2) Kitap Ekle")
    print("3) Kitap Sil")
    print("q) Çıkış")

    choice = input("Seçiminizi girin: ")

    if choice == '1':
        lib.list_books()
    elif choice == '2':
        lib.add_book()
    elif choice == '3':
        lib.remove_book()
    elif choice == 'q':
        print("Kütüphane Yönetim Sistemini kullandığınız için teşekkür ederiz.")
        break
    else:
        print("Geçersiz seçim. Lütfen tekrar deneyiniz.")
# Out:
# *** MENU ***
# 1) Kitapları Listele
# 2) Kitap Ekle
# 3) Kitap Sil
# q) Çıkış
# Seçiminizi girin: 2
# Kitap adını girin: 1984
# Yazarın adını girin: George Orwell
# Yayın yılını girin: 1949
# Sayfa sayısını girin:352
#  '1984' kitabı başarıyla eklendi.
#
# *** MENU ***
# 1) Kitapları Listele
# 2) Kitap Ekle
# 3) Kitap Sil
# q) Çıkış
# Seçiminizi girin: 2
# Kitap adını girin: Fareler ve İnsanlar
# Yazarın adını girin: John Steinbeck
# Yayın yılını girin: 1937
# Sayfa sayısını girin:111
#  'Fareler ve İnsanlar' kitabı başarıyla eklendi.
#
# *** MENU ***
# 1) Kitapları Listele
# 2) Kitap Ekle
# 3) Kitap Sil
# q) Çıkış
# Seçiminizi girin: 1
# Kitap Listesi:
# Kitap Adı: 1984, Yazar Adı: George Orwell
# Kitap Adı: Fareler ve İnsanlar, Yazar Adı: John Steinbeck
#
# *** MENU ***
# 1) Kitapları Listele
# 2) Kitap Ekle
# 3) Kitap Sil
# q) Çıkış
# Seçiminizi girin: 3
# Silmek istediğiniz kitabın adını girin: Fareler ve İnsanlar
# 'Fareler ve İnsanlar' kitabı başarıyla silindi.
#
# ...
